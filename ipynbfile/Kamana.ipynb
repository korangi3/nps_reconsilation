# %%
import pandas as pd
import numpy as np
import re

# %%
bank_statement_df = pd.read_excel(r"D:\For Auto Recon\BANK STATEMENT REPORT FOR RECONCILE Phase1-20230807T053815Z-001\BANK STATEMENT REPORT FOR RECONCILE Phase1\STATEMENT OF Kamana.xlsx",skiprows=1)
soa_statement_df = pd.read_csv(r"D:\For Auto Recon\SOA REPORT FOR RECONCILE Phase1-20230807T053702Z-001\SOA REPORT FOR RECONCILE Phase1\Commission Report (12_25_2020 to 07_17_2021)Kamana Bank.csv",encoding='latin-1')

# %%
bank_statement_df.head()
# Out:
#      TranDate ShowTranDate          Desc1   ValueDate  Debit  Credit  Balance  \
# 0  10/09/2077   10/09/2077     9841812052  10/09/2077      0      10        0
# 1  10/09/2077   10/09/2077  ~Date summary         NaN      0       0       10
# 2  17/11/2077   17/11/2077     9811390279  17/11/2077      0    5000        0
# 3  17/11/2077   17/11/2077     9845197463  17/11/2077      0    2000        0
# 4  17/11/2077   17/11/2077  ~Date summary         NaN      0       0     7010
#
#       TranId         Desc2   Desc3 OrderByDate  NostroBranch
# 0  HPP163451  100000212449  660184  25/12/2020          41.0
# 1        NaN           NaN     NaN  25/12/2020           NaN
# 2  HPP122548  100000329326  795104  01/03/2021          82.0
# 3  HPP114722  100000329188  795007  01/03/2021          20.0
# 4        NaN           NaN     NaN  01/03/2021           NaN

# %%
bank_statement_df = bank_statement_df.loc[bank_statement_df['Desc1'] != '~Date summary']

# %%
bank_statement_df.head()
# Out:
#      TranDate ShowTranDate       Desc1   ValueDate  Debit  Credit  Balance  \
# 0  10/09/2077   10/09/2077  9841812052  10/09/2077      0      10        0
# 2  17/11/2077   17/11/2077  9811390279  17/11/2077      0    5000        0
# 3  17/11/2077   17/11/2077  9845197463  17/11/2077      0    2000        0
# 5  18/11/2077   18/11/2077  9824035274  18/11/2077      0     500        0
# 6  18/11/2077   18/11/2077  9843732924  18/11/2077      0   20900        0
#
#       TranId         Desc2   Desc3 OrderByDate  NostroBranch
# 0  HPP163451  100000212449  660184  25/12/2020          41.0
# 2  HPP122548  100000329326  795104  01/03/2021          82.0
# 3  HPP114722  100000329188  795007  01/03/2021          20.0
# 5  HPP130336  100000331430  797377  02/03/2021          69.0
# 6  HPP133557  100000331509  797439  02/03/2021          77.0

# %%
for index, row in bank_statement_df.iterrows():
    if '100000' in row['Desc2']:
    # Split the description into words
        description_words = row['Desc2'].split()
        value = description_words[0]
        id = re.sub(r'10*', '', value, count=1)
        bank_statement_df.loc[index, 'Transaction Id'] = id
        
        # print(description_words)

# %%
bank_statement_df.head(20)
# Out:
#       TranDate ShowTranDate       Desc1   ValueDate  Debit  Credit  Balance  \
# 0   10/09/2077   10/09/2077  9841812052  10/09/2077      0      10        0
# 2   17/11/2077   17/11/2077  9811390279  17/11/2077      0    5000        0
# 3   17/11/2077   17/11/2077  9845197463  17/11/2077      0    2000        0
# 5   18/11/2077   18/11/2077  9824035274  18/11/2077      0     500        0
# 6   18/11/2077   18/11/2077  9843732924  18/11/2077      0   20900        0
# 7   18/11/2077   18/11/2077  9847547705  18/11/2077      0    1000        0
# 9   19/11/2077   19/11/2077  9809125280  19/11/2077      0    1400        0
# 10  19/11/2077   19/11/2077  9846844693  19/11/2077      0     700        0
# 11  19/11/2077   19/11/2077  9847013983  19/11/2077      0    3400        0
# 12  19/11/2077   19/11/2077  9847013983  19/11/2077      0   10000        0
# 13  19/11/2077   19/11/2077  9847013983  19/11/2077      0   10000        0
# ...

# %%
bank_statement_df['Transaction Id'].count()
# Out:
# 1272

# %%
# !pip install nepali_datetime

# %%
#  nepali_datetime.datetime.strptime(bank_statement_df['Tran'], "%m/%d/%Y")
